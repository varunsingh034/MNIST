# %% [markdown]
# Fetching Dataset
#
# pip install sklearn in terminal

# %%
import os
import cv2 
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 import cv2
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# uploading the dataset

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = tf.keras.utils.normalize(x_train,axis=1)
x_test = tf.keras.utils.normalize(x_test,axis=1)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
# Out:
# C:\Users\varun\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9743 - loss: 0.0818
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9823 - loss: 0.0540
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9873 - loss: 0.0398
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9902 - loss: 0.0317
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9907 - loss: 0.0272

# %%
model.save('handwritten.keras')
model = tf.keras.models.load_model('handwritten.keras')

# %%
imageNum=1
while os.path.isfile(f'digits/digit{imageNum}.png'):
    try: 
        img = cv2.imread(f'digits/digit{imageNum}.png')[:,:,0]
        img = np.invert(np.array([img]))
        prediction = model.predict(img)
        print(f'This digit is probably a {np.argmax(prediction)}')
        plt.imshow(img[0],cmap=plt.cm.binary)
        plt.show()
    
    except:
        print("Error;")

    finally:    
        imageNum += 1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# This digit is probably a 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# This digit is probably a 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This digit is probably a 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This digit is probably a 3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# This digit is probably a 8
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# This digit is probably a 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# This digit is probably a 4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# This digit is probably a 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# This digit is probably a 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# This digit is probably a 7
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# This digit is probably a 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# This digit is probably a 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# This digit is probably a 5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# This digit is probably a 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# This digit is probably a 7
